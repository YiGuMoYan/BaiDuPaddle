# %% [markdown]
# # 宝石的识别

# %%
import os
import zipfile
import random
import json
import cv2
import numpy as np
from PIL import Image
from matplotlib.pyplot import plot
import paddle
from paddle.io import Dataset
import paddle.nn as nn

# %% [markdown]
# # 1.数据准备

# %%
# 超参数
train_parameters = {
    # 输入图像的 shape
    "input_size": [3, 224, 224],
    # 分类数
    "class_dim": 25,
    # 原始数据集路径
    "src_path": r"E:\Python\BaiDuPaddle\宝石分类\data\archive_train.zip",
    # 解压目标路径
    "target_path": r"E:\Python\BaiDuPaddle\宝石分类\data\dataset",
    # train_data.txt 路径
    "train_list_path": "./train.txt",
    # eval_data.txt 路径
    "eval_list_path": "./eval.txt",
    # 标签字典
    "label_dict": {},
    # readme_json 路径
    "readme_path": r"E:\Python\BaiDuPaddle\宝石分类\data\readme.json",
    # 训练轮数
    "num_epochs": 10,
    # 批次大小
    "train_batch_size": 32,
    # 优化函数相关配置
    "learning_strategy": {
        # 超惨学习率
        "lr": 0.0005
    }
}

# %%
def unzip_data(src_path, target_path):
    '''
    解压原始数据集，将src_path路径下的zip包解压至data/dataset目录下
    '''
    if not os.path.isdir(target_path):
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()
    else:
        print("文件已解压")

# %%
def get_data_list(target_path, train_list_path, eval_list_path):
    '''
    生成数据列表
    '''
    #存放所有类别的信息
    class_detail = []
    #获取所有类别保存的文件夹名称
    data_list_path = target_path
    class_dirs = os.listdir(data_list_path)
    if '__MACOSX' in class_dirs:
        class_dirs.remove('__MACOSX')
    # #总的图像数量
    all_class_images = 0
    # #存放类别标签
    class_label = 0
    # #存放类别数目
    class_dim = 0
    # #存储要写进eval.txt和train.txt中的内容
    trainer_list = []
    eval_list = []
    #读取每个类别
    for class_dir in class_dirs:
        if class_dir != ".DS_Store":
            class_dim += 1
            #每个类别的信息
            class_detail_list = {}
            eval_sum = 0
            trainer_sum = 0
            #统计每个类别有多少张图片
            class_sum = 0
            #获取类别路径
            path = os.path.join(data_list_path, class_dir)
            # 获取所有图片
            img_paths = os.listdir(path)
            for img_path in img_paths:  # 遍历文件夹下的每个图片
                if img_path == '.DS_Store':
                    continue
                name_path = os.path.join(path, img_path)  # 每张图片的路径
                if class_sum % 15 == 0:  # 每10张图片取一个做验证数据
                    eval_sum += 1  # eval_sum为测试数据的数目
                    eval_list.append(name_path + "\t%d" % class_label + "\n")
                else:
                    trainer_sum += 1
                    trainer_list.append(name_path + "\t%d" % class_label + "\n")  #trainer_sum测试数据的数目
                class_sum += 1  #每类图片的数目
                all_class_images += 1  #所有类图片的数目

            # 说明的json文件的class_detail数据
            class_detail_list['class_name'] = class_dir  #类别名称
            class_detail_list['class_label'] = class_label  #类别标签
            class_detail_list['class_eval_images'] = eval_sum  #该类数据的测试集数目
            class_detail_list['class_trainer_images'] = trainer_sum  #该类数据的训练集数目
            class_detail.append(class_detail_list)
            #初始化标签列表
            train_parameters['label_dict'][str(class_label)] = class_dir
            class_label += 1

    #初始化分类数
    train_parameters['class_dim'] = class_dim
    print(train_parameters)
    #乱序
    random.shuffle(eval_list)
    with open(eval_list_path, 'a') as f:
        for eval_image in eval_list:
            f.write(eval_image)
            #乱序
    random.shuffle(trainer_list)
    with open(train_list_path, 'a') as f2:
        for train_image in trainer_list:
            f2.write(train_image)

            # 说明的json文件信息
    readjson = {}
    readjson['all_class_name'] = data_list_path  #文件父目录
    readjson['all_class_images'] = all_class_images
    readjson['class_detail'] = class_detail
    jsons = json.dumps(readjson, sort_keys=True, indent=4, separators=(',', ': '))
    with open(train_parameters['readme_path'], 'w') as f:
        f.write(jsons)
    print('生成数据列表完成！')

# %%
'''
参数初始化
'''
src_path = train_parameters['src_path']
target_path = train_parameters['target_path']
train_list_path = train_parameters['train_list_path']
eval_list_path = train_parameters['eval_list_path']
batch_size = train_parameters['train_batch_size']
'''
解压原始数据到指定路径
'''
unzip_data(src_path, target_path)

'''
划分训练集与验证集，乱序，生成数据列表
'''
#每次生成数据列表前，首先清空train.txt和eval.txt
with open(train_list_path, 'w') as f:
    f.seek(0)
    f.truncate()
with open(eval_list_path, 'w') as f:
    f.seek(0)
    f.truncate()

#生成数据列表
get_data_list(target_path, train_list_path, eval_list_path)
# Out:
# 文件已解压
# {'input_size': [3, 224, 224], 'class_dim': 25, 'src_path': 'E:\\Python\\BaiDuPaddle\\宝石分类\\data\\archive_train.zip', 'target_path': 'E:\\Python\\BaiDuPaddle\\宝石分类\\data\\dataset', 'train_list_path': './train.txt', 'eval_list_path': './eval.txt', 'label_dict': {'0': 'Alexandrite', '1': 'Almandine', '2': 'Benitoite', '3': 'Beryl Golden', '4': 'Carnelian', '5': 'Cats Eye', '6': 'Danburite', '7': 'Diamond', '8': 'Emerald', '9': 'Fluorite', '10': 'Garnet Red', '11': 'Hessonite', '12': 'Iolite', '13': 'Jade', '14': 'Kunzite', '15': 'Labradorite', '16': 'Malachite', '17': 'Onyx Black', '18': 'Pearl', '19': 'Quartz Beer', '20': 'Rhodochrosite', '21': 'Sapphire Blue', '22': 'Tanzanite', '23': 'Variscite', '24': 'Zircon'}, 'readme_path': 'E:\\Python\\BaiDuPaddle\\宝石分类\\data\\readme.json', 'num_epochs': 10, 'train_batch_size': 32, 'learning_strategy': {'lr': 0.0005}}
# 生成数据列表完成！

# %%
class Reader(Dataset):
    def __init__(self, data_path, mode='train'):
        """
        数据读取器
        :param data_path: 数据集所在路径
        :param mode: train or eval
        """
        super().__init__()
        self.dara_path = data_path
        self.img_path = []
        self.labels = []

        if mode == "train":
            with open(os.path.join(self.dara_path, "train.txt"), "r", encoding="utf-8") as f:
                self.info = f.readlines()
                for img_info in self.info:
                    img_path, label = img_info.strip().split("\t")
                    self.img_path.append(img_path)
                    self.labels.append(int(label))
        else:
            with open(os.path.join(self.dara_path, "eval.txt"), "r", encoding="utf-8") as f:
                self.info = f.readlines()
                for img_info in self.info:
                    img_path, label = img_info.strip().split("\t")
                    self.img_path.append(img_path)
                    self.labels.append(int(label))

    def __getitem__(self, index):
        img_path = self.img_path[index]
        label = self.labels[index]
        img = Image.open(img_path)
        # 确保 RGB 通道
        if img.mode != 'RGB':
            img = img.convert("RGB")
        # 更改大小
        img = img.resize((224, 224), Image.BILINEAR)
        # 转为 numpy 数组
        img = np.array(img).astype("float32")
        # 将代表通道的维度提前
        # 将数据规划到 0-1
        img = img.transpose((2, 0, 1)) / 255
        # 处理label
        label = np.array([label], dtype="int64")
        return img, label

    def __len__(self):
        return len(self.img_path)

# %%
train_dataset = Reader(r"E:\Python\BaiDuPaddle\宝石分类\\", mode="train")
eval_dataset = Reader(r"E:\Python\BaiDuPaddle\宝石分类\\", mode="eval")

train_loader = paddle.io.DataLoader(train_dataset)
eval_loader = paddle.io.DataLoader(eval_dataset)

# %% [markdown]
# # 2.定义模型

# %%
class MyDNN(nn.Layer):
    def __init__(self):
        super(MyDNN, self).__init__()
        self.linear1 = nn.Linear(224 * 224 * 3, 1024)
        self.linear2 = nn.Linear(1024, 512)
        self.linear3 = nn.Linear(512, 256)
        self.linear4 = nn.Linear(256, 128)
        self.linear5 = nn.Linear(128, 25)
        self.relu1 = nn.ReLU()
        self.relu3 = nn.ReLU()
        self.relu4 = nn.ReLU()

    def forward(self, input):
        x = self.linear1(input)
        x = self.relu1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        x = self.relu3(x)
        x = self.linear4(x)
        x = self.relu4(x)
        x = self.linear5(x)
        return x

# %%
from matplotlib import pyplot as plt

Batch=0
Batchs=[]
all_train_accs=[]
def draw_train_acc(Batchs, train_accs):
    title="training accs"
    plt.title(title, fontsize=24)
    plt.xlabel("batch", fontsize=14)
    plt.ylabel("acc", fontsize=14)
    plt.plot(Batchs, train_accs, color='green', label='training accs')
    plt.legend()
    plt.grid()
    plt.show()

all_train_loss=[]
def draw_train_loss(Batchs, train_loss):
    title="training loss"
    plt.title(title, fontsize=24)
    plt.xlabel("batch", fontsize=14)
    plt.ylabel("loss", fontsize=14)
    plt.plot(Batchs, train_loss, color='red', label='training loss')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# # 3.训练模型

# %%
model = MyDNN()
model.train()
cross_entropy = paddle.nn.CrossEntropyLoss()
opt = paddle.optimizer.SGD(learning_rate=train_parameters["learning_strategy"]["lr"], parameters=model.parameters())
epochs_num = train_parameters["num_epochs"]

for epoch in range(epochs_num):
    for batch_id, data in enumerate(train_loader):
        img = data[0]
        label = data[1]
        img = img.flatten(1)
        predict = model(img)
        loss = cross_entropy(predict, label)
        acc = paddle.metric.accuracy(predict, label)
        loss.backward()
        opt.step()
        opt.clear_grad()
        if batch_id != 0 and batch_id % 5 == 0:
            Batch += 5
            Batchs.append(Batch)
            print(f"epoch:{epoch},step{batch_id},train_loss{loss.numpy()[0]}, train_acc{acc.numpy()[0]}")
        paddle.save(model.state_dict(), "MyDNN")
# Out:
# epoch:0,step5,train_loss5.284036159515381, train_acc0.0
# epoch:0,step10,train_loss3.5361685752868652, train_acc0.0
# epoch:0,step15,train_loss4.816277503967285, train_acc0.0
# epoch:0,step20,train_loss3.1913626194000244, train_acc0.0
# epoch:0,step25,train_loss2.1728124618530273, train_acc0.0
# epoch:0,step30,train_loss3.5143251419067383, train_acc0.0
# epoch:0,step35,train_loss4.311332702636719, train_acc0.0
# epoch:0,step40,train_loss4.915657043457031, train_acc0.0
# epoch:0,step45,train_loss3.639138698577881, train_acc0.0
# epoch:0,step50,train_loss3.6179466247558594, train_acc0.0
# epoch:0,step55,train_loss3.780313014984131, train_acc0.0
# epoch:0,step60,train_loss3.3033974170684814, train_acc0.0
# epoch:0,step65,train_loss3.3663084506988525, train_acc0.0
# epoch:0,step70,train_loss4.239714622497559, train_acc0.0
# epoch:0,step75,train_loss3.251542806625366, train_acc0.0
# epoch:0,step80,train_loss3.7533719539642334, train_acc0.0
# epoch:0,step85,train_loss6.0252227783203125, train_acc0.0
# epoch:0,step90,train_loss5.5607709884643555, train_acc0.0
# epoch:0,step95,train_loss3.0615313053131104, train_acc0.0
# epoch:0,step100,train_loss2.7617554664611816, train_acc0.0
# epoch:0,step105,train_loss5.604462623596191, train_acc0.0
# epoch:0,step110,train_loss4.943976879119873, train_acc0.0
# epoch:0,step115,train_loss3.2985944747924805, train_acc0.0
# epoch:0,step120,train_loss2.3304691314697266, train_acc0.0
# epoch:0,step125,train_loss2.6141152381896973, train_acc0.0
# epoch:0,step130,train_loss2.5489730834960938, train_acc0.0
# epoch:0,step135,train_loss3.620908260345459, train_acc0.0
# epoch:0,step140,train_loss4.774405479431152, train_acc0.0
# epoch:0,step145,train_loss3.27162766456604, train_acc0.0
# epoch:0,step150,train_loss3.3958353996276855, train_acc0.0
# epoch:0,step155,train_loss3.102489709854126, train_acc0.0
# epoch:0,step160,train_loss3.889097213745117, train_acc0.0
# epoch:0,step165,train_loss3.882333278656006, train_acc0.0
# epoch:0,step170,train_loss3.505791664123535, train_acc0.0
# epoch:0,step175,train_loss2.463285207748413, train_acc0.0
# epoch:0,step180,train_loss0.4262298047542572, train_acc1.0
# epoch:0,step185,train_loss3.2570958137512207, train_acc0.0
# epoch:0,step190,train_loss1.4763007164001465, train_acc1.0
# epoch:0,step195,train_loss3.358199119567871, train_acc0.0
# epoch:0,step200,train_loss2.5340638160705566, train_acc0.0
# epoch:0,step205,train_loss3.5672624111175537, train_acc0.0
# epoch:0,step210,train_loss2.648900270462036, train_acc0.0
# epoch:0,step215,train_loss3.137860059738159, train_acc0.0
# epoch:0,step220,train_loss3.629976272583008, train_acc0.0
# epoch:0,step225,train_loss2.3278212547302246, train_acc0.0
# epoch:0,step230,train_loss3.488335609436035, train_acc0.0
# epoch:0,step235,train_loss3.7002782821655273, train_acc0.0
# epoch:0,step240,train_loss1.4388188123703003, train_acc1.0
# epoch:0,step245,train_loss3.6924633979797363, train_acc0.0
# epoch:0,step250,train_loss5.293303489685059, train_acc0.0
# epoch:0,step255,train_loss3.7627036571502686, train_acc0.0
# epoch:0,step260,train_loss1.3263078927993774, train_acc1.0
# epoch:0,step265,train_loss2.7781620025634766, train_acc0.0
# epoch:0,step270,train_loss3.0310771465301514, train_acc0.0
# epoch:0,step275,train_loss1.714627981185913, train_acc1.0
# epoch:0,step280,train_loss3.130706548690796, train_acc0.0
# epoch:0,step285,train_loss2.1833090782165527, train_acc0.0
# epoch:0,step290,train_loss3.38983154296875, train_acc0.0
# epoch:0,step295,train_loss3.688760995864868, train_acc0.0
# epoch:0,step300,train_loss2.799203395843506, train_acc0.0
# epoch:0,step305,train_loss4.377453804016113, train_acc0.0
# epoch:0,step310,train_loss3.1357743740081787, train_acc0.0
# epoch:0,step315,train_loss2.899441719055176, train_acc0.0
# epoch:0,step320,train_loss3.677067279815674, train_acc0.0
# epoch:0,step325,train_loss3.0024640560150146, train_acc0.0
# epoch:0,step330,train_loss3.913522243499756, train_acc0.0
# epoch:0,step335,train_loss2.311420440673828, train_acc0.0
# epoch:0,step340,train_loss2.236802577972412, train_acc0.0
# epoch:0,step345,train_loss2.3069570064544678, train_acc0.0
# epoch:0,step350,train_loss3.283754825592041, train_acc0.0
# epoch:0,step355,train_loss2.9339118003845215, train_acc0.0
# epoch:0,step360,train_loss3.006864547729492, train_acc0.0
# epoch:0,step365,train_loss3.762481927871704, train_acc0.0
# epoch:0,step370,train_loss3.2205615043640137, train_acc0.0
# epoch:0,step375,train_loss3.201846122741699, train_acc0.0
# epoch:0,step380,train_loss3.274348497390747, train_acc0.0
# epoch:0,step385,train_loss3.3961215019226074, train_acc0.0
# epoch:0,step390,train_loss3.5815281867980957, train_acc0.0
# epoch:0,step395,train_loss3.3590495586395264, train_acc0.0
# epoch:0,step400,train_loss3.738002300262451, train_acc0.0
# epoch:0,step405,train_loss3.3751063346862793, train_acc0.0
# epoch:0,step410,train_loss3.133237361907959, train_acc0.0
# epoch:0,step415,train_loss2.457921028137207, train_acc1.0
# epoch:0,step420,train_loss3.7930562496185303, train_acc0.0
# epoch:0,step425,train_loss3.8703248500823975, train_acc0.0
# epoch:0,step430,train_loss3.434272050857544, train_acc0.0
# epoch:0,step435,train_loss2.374631404876709, train_acc0.0
# epoch:0,step440,train_loss3.793595790863037, train_acc0.0
# epoch:0,step445,train_loss2.6767168045043945, train_acc1.0
# epoch:0,step450,train_loss3.687403678894043, train_acc0.0
# epoch:0,step455,train_loss3.7991228103637695, train_acc0.0
# epoch:0,step460,train_loss2.797516107559204, train_acc0.0
# epoch:0,step465,train_loss4.015584945678711, train_acc0.0
# epoch:0,step470,train_loss3.1359047889709473, train_acc0.0
# epoch:0,step475,train_loss3.2549262046813965, train_acc0.0
# epoch:0,step480,train_loss3.9824233055114746, train_acc0.0
# epoch:0,step485,train_loss2.8970439434051514, train_acc0.0
# epoch:0,step490,train_loss3.290308952331543, train_acc0.0
# epoch:0,step495,train_loss2.581268072128296, train_acc0.0
# epoch:0,step500,train_loss3.4422426223754883, train_acc0.0
# epoch:0,step505,train_loss3.6968014240264893, train_acc0.0
# epoch:0,step510,train_loss2.49938702583313, train_acc0.0
# epoch:0,step515,train_loss4.13230037689209, train_acc0.0
# epoch:0,step520,train_loss3.771561861038208, train_acc0.0
# epoch:0,step525,train_loss3.0002312660217285, train_acc0.0
# epoch:0,step530,train_loss3.4147353172302246, train_acc0.0
# epoch:0,step535,train_loss3.2139077186584473, train_acc0.0
# epoch:0,step540,train_loss4.096416473388672, train_acc0.0
# epoch:0,step545,train_loss3.0086593627929688, train_acc0.0
# epoch:0,step550,train_loss3.329784393310547, train_acc0.0
# epoch:0,step555,train_loss3.0147271156311035, train_acc0.0
# epoch:0,step560,train_loss2.6906919479370117, train_acc0.0
# epoch:0,step565,train_loss2.810652732849121, train_acc0.0
# epoch:0,step570,train_loss4.14322566986084, train_acc0.0
# epoch:0,step575,train_loss3.500804901123047, train_acc0.0
# epoch:0,step580,train_loss2.556704521179199, train_acc0.0
# epoch:0,step585,train_loss1.850037693977356, train_acc1.0
# epoch:0,step590,train_loss2.2095446586608887, train_acc0.0
# epoch:0,step595,train_loss1.8647665977478027, train_acc1.0
# epoch:0,step600,train_loss4.4229655265808105, train_acc0.0
# epoch:0,step605,train_loss3.311608076095581, train_acc0.0
# epoch:0,step610,train_loss2.083963632583618, train_acc1.0
# epoch:0,step615,train_loss3.3467302322387695, train_acc0.0
# epoch:0,step620,train_loss2.953528881072998, train_acc0.0
# epoch:0,step625,train_loss2.623770236968994, train_acc0.0
# epoch:0,step630,train_loss4.082785606384277, train_acc0.0
# epoch:0,step635,train_loss2.9739937782287598, train_acc0.0
# epoch:0,step640,train_loss2.8019838333129883, train_acc0.0
# epoch:0,step645,train_loss2.5127899646759033, train_acc1.0
# epoch:0,step650,train_loss2.654822826385498, train_acc1.0
# epoch:0,step655,train_loss3.607961654663086, train_acc0.0
# epoch:0,step660,train_loss3.3787758350372314, train_acc0.0
# epoch:0,step665,train_loss2.976078510284424, train_acc0.0
# epoch:0,step670,train_loss1.3968415260314941, train_acc1.0
# epoch:0,step675,train_loss3.2196435928344727, train_acc0.0
# epoch:0,step680,train_loss3.5079474449157715, train_acc0.0
# epoch:0,step685,train_loss3.134091377258301, train_acc0.0
# epoch:0,step690,train_loss3.567422389984131, train_acc0.0
# epoch:0,step695,train_loss3.338338851928711, train_acc0.0
# epoch:0,step700,train_loss3.407996416091919, train_acc0.0
# epoch:0,step705,train_loss2.6471660137176514, train_acc0.0
# epoch:0,step710,train_loss3.2377207279205322, train_acc0.0
# epoch:0,step715,train_loss2.3957958221435547, train_acc0.0
# epoch:0,step720,train_loss0.19608885049819946, train_acc1.0
# epoch:0,step725,train_loss3.227405548095703, train_acc0.0
# epoch:0,step730,train_loss3.5841317176818848, train_acc0.0
# epoch:0,step735,train_loss1.4297558069229126, train_acc1.0
# epoch:0,step740,train_loss3.4463553428649902, train_acc0.0
# epoch:1,step5,train_loss2.5338590145111084, train_acc0.0
# epoch:1,step10,train_loss2.243931770324707, train_acc0.0
# epoch:1,step15,train_loss4.116504192352295, train_acc0.0
# epoch:1,step20,train_loss2.822120189666748, train_acc0.0
# epoch:1,step25,train_loss2.654836416244507, train_acc0.0
# epoch:1,step30,train_loss3.7531847953796387, train_acc0.0
# epoch:1,step35,train_loss3.4242491722106934, train_acc0.0
# epoch:1,step40,train_loss3.4593544006347656, train_acc0.0
# epoch:1,step45,train_loss3.248878240585327, train_acc0.0
# epoch:1,step50,train_loss2.536527395248413, train_acc0.0
# epoch:1,step55,train_loss2.924474000930786, train_acc0.0
# epoch:1,step60,train_loss2.351271629333496, train_acc0.0
# epoch:1,step65,train_loss2.922929525375366, train_acc0.0
# epoch:1,step70,train_loss2.833225727081299, train_acc0.0
# epoch:1,step75,train_loss4.472995758056641, train_acc0.0
# epoch:1,step80,train_loss2.709984302520752, train_acc0.0
# epoch:1,step85,train_loss4.653750419616699, train_acc0.0
# epoch:1,step90,train_loss3.936476707458496, train_acc0.0
# epoch:1,step95,train_loss3.9517157077789307, train_acc0.0
# epoch:1,step100,train_loss2.7305502891540527, train_acc0.0
# epoch:1,step105,train_loss4.993524551391602, train_acc0.0
# epoch:1,step110,train_loss3.31500244140625, train_acc0.0
# epoch:1,step115,train_loss3.0194602012634277, train_acc0.0
# epoch:1,step120,train_loss2.961423397064209, train_acc0.0
# epoch:1,step125,train_loss2.9072957038879395, train_acc0.0
# epoch:1,step130,train_loss2.863283157348633, train_acc0.0
# epoch:1,step135,train_loss2.5289998054504395, train_acc0.0
# epoch:1,step140,train_loss3.5722851753234863, train_acc0.0
# epoch:1,step145,train_loss3.0516467094421387, train_acc0.0
# epoch:1,step150,train_loss3.718696117401123, train_acc0.0
# epoch:1,step155,train_loss0.9172298312187195, train_acc1.0
# epoch:1,step160,train_loss2.8500216007232666, train_acc0.0
# epoch:1,step165,train_loss2.8752644062042236, train_acc0.0
# epoch:1,step170,train_loss3.100855588912964, train_acc0.0
# epoch:1,step175,train_loss2.719897747039795, train_acc0.0
# epoch:1,step180,train_loss0.12814341485500336, train_acc1.0
# epoch:1,step185,train_loss3.0092363357543945, train_acc0.0
# epoch:1,step190,train_loss0.6517842411994934, train_acc1.0
# epoch:1,step195,train_loss3.842487335205078, train_acc0.0
# epoch:1,step200,train_loss2.593512773513794, train_acc0.0
# epoch:1,step205,train_loss2.579150676727295, train_acc0.0
# epoch:1,step210,train_loss3.905752182006836, train_acc0.0
# epoch:1,step215,train_loss2.6246654987335205, train_acc0.0
# epoch:1,step220,train_loss4.638182640075684, train_acc0.0
# epoch:1,step225,train_loss2.6508917808532715, train_acc0.0
# epoch:1,step230,train_loss3.220177173614502, train_acc0.0
# epoch:1,step235,train_loss3.2859625816345215, train_acc0.0
# epoch:1,step240,train_loss1.5821523666381836, train_acc1.0
# epoch:1,step245,train_loss3.806788682937622, train_acc0.0
# epoch:1,step250,train_loss4.2835540771484375, train_acc0.0
# epoch:1,step255,train_loss2.7476227283477783, train_acc0.0
# epoch:1,step260,train_loss0.5042752623558044, train_acc1.0
# epoch:1,step265,train_loss2.350714921951294, train_acc0.0
# epoch:1,step270,train_loss4.165680885314941, train_acc0.0
# epoch:1,step275,train_loss2.0982038974761963, train_acc0.0
# epoch:1,step280,train_loss3.6239168643951416, train_acc0.0
# epoch:1,step285,train_loss2.191338300704956, train_acc0.0
# epoch:1,step290,train_loss2.4422731399536133, train_acc0.0
# epoch:1,step295,train_loss1.7763922214508057, train_acc0.0
# epoch:1,step300,train_loss2.2092013359069824, train_acc1.0
# epoch:1,step305,train_loss4.474220275878906, train_acc0.0
# epoch:1,step310,train_loss3.332512855529785, train_acc0.0
# epoch:1,step315,train_loss2.7663373947143555, train_acc0.0
# epoch:1,step320,train_loss3.16684889793396, train_acc0.0
# epoch:1,step325,train_loss3.2045397758483887, train_acc0.0
# epoch:1,step330,train_loss3.36021089553833, train_acc0.0
# epoch:1,step335,train_loss2.3387515544891357, train_acc0.0
# epoch:1,step340,train_loss1.8715187311172485, train_acc1.0
# epoch:1,step345,train_loss2.9126086235046387, train_acc0.0
# epoch:1,step350,train_loss1.9830141067504883, train_acc1.0
# epoch:1,step355,train_loss3.331672430038452, train_acc0.0
# epoch:1,step360,train_loss1.5845355987548828, train_acc0.0
# epoch:1,step365,train_loss3.131608247756958, train_acc0.0
# epoch:1,step370,train_loss3.301197052001953, train_acc0.0
# epoch:1,step375,train_loss3.131654739379883, train_acc0.0
# epoch:1,step380,train_loss3.154959201812744, train_acc0.0
# epoch:1,step385,train_loss2.980051279067993, train_acc0.0
# epoch:1,step390,train_loss2.1924471855163574, train_acc0.0
# epoch:1,step395,train_loss2.991219997406006, train_acc0.0
# epoch:1,step400,train_loss4.465037822723389, train_acc0.0
# epoch:1,step405,train_loss1.3523958921432495, train_acc1.0
# epoch:1,step410,train_loss2.7027058601379395, train_acc0.0
# epoch:1,step415,train_loss2.749891519546509, train_acc0.0
# epoch:1,step420,train_loss3.541243553161621, train_acc0.0
# epoch:1,step425,train_loss3.891866683959961, train_acc0.0
# epoch:1,step430,train_loss2.3827786445617676, train_acc1.0
# epoch:1,step435,train_loss0.4686114192008972, train_acc1.0
# epoch:1,step440,train_loss3.152090549468994, train_acc0.0
# epoch:1,step445,train_loss2.5162277221679688, train_acc0.0
# epoch:1,step450,train_loss3.2511730194091797, train_acc0.0
# epoch:1,step455,train_loss2.5163209438323975, train_acc0.0
# epoch:1,step460,train_loss2.820502281188965, train_acc0.0
# epoch:1,step465,train_loss3.5591022968292236, train_acc0.0
# epoch:1,step470,train_loss1.847661018371582, train_acc0.0
# epoch:1,step475,train_loss3.3633768558502197, train_acc0.0
# epoch:1,step480,train_loss3.435723304748535, train_acc0.0
# epoch:1,step485,train_loss3.3423211574554443, train_acc0.0
# epoch:1,step490,train_loss3.283052921295166, train_acc0.0
# epoch:1,step495,train_loss3.0613901615142822, train_acc0.0
# epoch:1,step500,train_loss3.4493496417999268, train_acc0.0
# epoch:1,step505,train_loss2.532552480697632, train_acc0.0
# epoch:1,step510,train_loss1.5445531606674194, train_acc1.0
# epoch:1,step515,train_loss3.079477310180664, train_acc0.0
# epoch:1,step520,train_loss2.3670454025268555, train_acc0.0
# epoch:1,step525,train_loss1.5191755294799805, train_acc0.0
# epoch:1,step530,train_loss3.006129026412964, train_acc0.0
# epoch:1,step535,train_loss2.065977096557617, train_acc0.0
# epoch:1,step540,train_loss4.041862964630127, train_acc0.0
# epoch:1,step545,train_loss3.612382411956787, train_acc0.0
# epoch:1,step550,train_loss2.7905890941619873, train_acc0.0
# epoch:1,step555,train_loss4.1818718910217285, train_acc0.0
# epoch:1,step560,train_loss2.453625202178955, train_acc0.0
# epoch:1,step565,train_loss3.108818292617798, train_acc0.0
# epoch:1,step570,train_loss4.446271896362305, train_acc0.0
# epoch:1,step575,train_loss3.8994712829589844, train_acc0.0
# epoch:1,step580,train_loss1.3399745225906372, train_acc1.0
# epoch:1,step585,train_loss1.3762588500976562, train_acc1.0
# epoch:1,step590,train_loss2.1401491165161133, train_acc0.0
# epoch:1,step595,train_loss1.902968406677246, train_acc1.0
# epoch:1,step600,train_loss3.342003345489502, train_acc0.0
# epoch:1,step605,train_loss3.210200786590576, train_acc0.0
# epoch:1,step610,train_loss1.5632908344268799, train_acc1.0
# epoch:1,step615,train_loss2.6429059505462646, train_acc0.0
# epoch:1,step620,train_loss2.2247397899627686, train_acc0.0
# epoch:1,step625,train_loss1.8158445358276367, train_acc0.0
# epoch:1,step630,train_loss5.193220138549805, train_acc0.0
# epoch:1,step635,train_loss1.7531301975250244, train_acc0.0
# epoch:1,step640,train_loss2.7989823818206787, train_acc0.0
# epoch:1,step645,train_loss1.732572317123413, train_acc1.0
# epoch:1,step650,train_loss2.5947601795196533, train_acc0.0
# epoch:1,step655,train_loss2.43001127243042, train_acc0.0
# epoch:1,step660,train_loss2.5933949947357178, train_acc0.0
# epoch:1,step665,train_loss2.8495986461639404, train_acc0.0
# epoch:1,step670,train_loss0.7163671255111694, train_acc1.0
# epoch:1,step675,train_loss4.005284309387207, train_acc0.0
# epoch:1,step680,train_loss3.1606621742248535, train_acc0.0
# epoch:1,step685,train_loss2.728325605392456, train_acc0.0
# epoch:1,step690,train_loss3.2666566371917725, train_acc0.0
# epoch:1,step695,train_loss1.9247936010360718, train_acc1.0
# epoch:1,step700,train_loss3.1421897411346436, train_acc0.0
# epoch:1,step705,train_loss2.333588123321533, train_acc0.0
# epoch:1,step710,train_loss3.399768590927124, train_acc0.0
# epoch:1,step715,train_loss1.6790199279785156, train_acc1.0
# epoch:1,step720,train_loss0.10063247382640839, train_acc1.0
# epoch:1,step725,train_loss3.390831470489502, train_acc0.0
# epoch:1,step730,train_loss2.278947353363037, train_acc0.0
# epoch:1,step735,train_loss1.3167592287063599, train_acc1.0
# epoch:1,step740,train_loss2.5128726959228516, train_acc0.0
# epoch:2,step5,train_loss1.2866551876068115, train_acc1.0
# epoch:2,step10,train_loss1.9152708053588867, train_acc0.0
# epoch:2,step15,train_loss3.5159506797790527, train_acc0.0
# epoch:2,step20,train_loss1.3629357814788818, train_acc0.0
# epoch:2,step25,train_loss2.225308418273926, train_acc0.0
# epoch:2,step30,train_loss3.320453643798828, train_acc0.0
# epoch:2,step35,train_loss2.964554786682129, train_acc0.0
# epoch:2,step40,train_loss1.2480599880218506, train_acc1.0
# epoch:2,step45,train_loss3.5302202701568604, train_acc0.0
# epoch:2,step50,train_loss2.4916789531707764, train_acc0.0
# epoch:2,step55,train_loss2.161388874053955, train_acc0.0
# epoch:2,step60,train_loss1.4588522911071777, train_acc1.0
# epoch:2,step65,train_loss2.338472604751587, train_acc0.0
# epoch:2,step70,train_loss2.137688636779785, train_acc0.0
# epoch:2,step75,train_loss4.897624969482422, train_acc0.0
# epoch:2,step80,train_loss3.378566026687622, train_acc0.0
# epoch:2,step85,train_loss3.2019004821777344, train_acc0.0
# epoch:2,step90,train_loss3.8690171241760254, train_acc0.0
# epoch:2,step95,train_loss3.0162353515625, train_acc0.0
# epoch:2,step100,train_loss2.6306569576263428, train_acc0.0
# epoch:2,step105,train_loss4.065555095672607, train_acc0.0
# epoch:2,step110,train_loss2.829984426498413, train_acc0.0
# epoch:2,step115,train_loss3.191635847091675, train_acc0.0
# epoch:2,step120,train_loss2.992201328277588, train_acc0.0
# epoch:2,step125,train_loss2.5500872135162354, train_acc0.0
# epoch:2,step130,train_loss2.4695615768432617, train_acc0.0
# epoch:2,step135,train_loss2.653146743774414, train_acc0.0
# epoch:2,step140,train_loss3.537432909011841, train_acc0.0
# epoch:2,step145,train_loss2.995255708694458, train_acc0.0
# epoch:2,step150,train_loss3.064753770828247, train_acc0.0
# epoch:2,step155,train_loss0.4611605405807495, train_acc1.0
# epoch:2,step160,train_loss2.1919212341308594, train_acc0.0
# epoch:2,step165,train_loss3.0013322830200195, train_acc0.0
# epoch:2,step170,train_loss2.8972816467285156, train_acc0.0
# epoch:2,step175,train_loss1.9845705032348633, train_acc1.0
# epoch:2,step180,train_loss0.03052448108792305, train_acc1.0
# epoch:2,step185,train_loss2.463102340698242, train_acc0.0
# epoch:2,step190,train_loss0.31637775897979736, train_acc1.0
# epoch:2,step195,train_loss3.174706220626831, train_acc0.0
# epoch:2,step200,train_loss1.9295684099197388, train_acc0.0
# epoch:2,step205,train_loss2.285890579223633, train_acc0.0
# epoch:2,step210,train_loss3.4561612606048584, train_acc0.0
# epoch:2,step215,train_loss1.9339933395385742, train_acc0.0
# epoch:2,step220,train_loss3.6314165592193604, train_acc0.0
# epoch:2,step225,train_loss2.9094862937927246, train_acc0.0
# epoch:2,step230,train_loss2.403456926345825, train_acc0.0
# epoch:2,step235,train_loss4.038876533508301, train_acc0.0
# epoch:2,step240,train_loss1.434303879737854, train_acc1.0
# epoch:2,step245,train_loss4.259474754333496, train_acc0.0
# epoch:2,step250,train_loss4.61615514755249, train_acc0.0
# epoch:2,step255,train_loss2.512266159057617, train_acc0.0
# epoch:2,step260,train_loss0.2660006582736969, train_acc1.0
# epoch:2,step265,train_loss2.7923498153686523, train_acc0.0
# epoch:2,step270,train_loss3.0702028274536133, train_acc0.0
# epoch:2,step275,train_loss1.5693230628967285, train_acc0.0
# epoch:2,step280,train_loss2.9635751247406006, train_acc0.0
# epoch:2,step285,train_loss1.8583698272705078, train_acc1.0
# epoch:2,step290,train_loss1.999577283859253, train_acc0.0
# epoch:2,step295,train_loss1.518602967262268, train_acc0.0
# epoch:2,step300,train_loss1.4971623420715332, train_acc1.0
# epoch:2,step305,train_loss4.523537635803223, train_acc0.0
# epoch:2,step310,train_loss2.359382152557373, train_acc0.0
# epoch:2,step315,train_loss2.130227565765381, train_acc0.0
# epoch:2,step320,train_loss3.674121379852295, train_acc0.0
# epoch:2,step325,train_loss3.039827346801758, train_acc0.0
# epoch:2,step330,train_loss4.094473361968994, train_acc0.0
# epoch:2,step335,train_loss0.9208727478981018, train_acc1.0
# epoch:2,step340,train_loss1.9212578535079956, train_acc0.0
# epoch:2,step345,train_loss2.9516146183013916, train_acc0.0
# epoch:2,step350,train_loss1.2127835750579834, train_acc1.0
# epoch:2,step355,train_loss3.5442283153533936, train_acc0.0
# epoch:2,step360,train_loss0.5167874693870544, train_acc1.0
# epoch:2,step365,train_loss3.1160144805908203, train_acc0.0
# epoch:2,step370,train_loss3.738415241241455, train_acc0.0
# epoch:2,step375,train_loss2.417336940765381, train_acc0.0
# epoch:2,step380,train_loss0.9306424856185913, train_acc1.0
# epoch:2,step385,train_loss2.5820980072021484, train_acc0.0
# epoch:2,step390,train_loss1.9749152660369873, train_acc0.0
# epoch:2,step395,train_loss2.1355762481689453, train_acc1.0
# epoch:2,step400,train_loss4.585353851318359, train_acc0.0
# epoch:2,step405,train_loss0.8699153065681458, train_acc1.0
# epoch:2,step410,train_loss1.5865219831466675, train_acc1.0
# epoch:2,step415,train_loss2.223727226257324, train_acc0.0
# epoch:2,step420,train_loss4.0758819580078125, train_acc0.0
# epoch:2,step425,train_loss3.850090503692627, train_acc0.0
# epoch:2,step430,train_loss1.9633493423461914, train_acc0.0
# epoch:2,step435,train_loss0.2321578413248062, train_acc1.0
# epoch:2,step440,train_loss3.2728638648986816, train_acc0.0
# epoch:2,step445,train_loss2.4894356727600098, train_acc0.0
# epoch:2,step450,train_loss3.3833796977996826, train_acc0.0
# epoch:2,step455,train_loss0.8299803733825684, train_acc1.0
# epoch:2,step460,train_loss2.8055877685546875, train_acc0.0
# epoch:2,step465,train_loss3.0545997619628906, train_acc0.0
# epoch:2,step470,train_loss1.5871144533157349, train_acc0.0
# epoch:2,step475,train_loss3.0026111602783203, train_acc0.0
# epoch:2,step480,train_loss5.222273826599121, train_acc0.0
# epoch:2,step485,train_loss2.993140697479248, train_acc0.0
# epoch:2,step490,train_loss3.388953447341919, train_acc0.0
# epoch:2,step495,train_loss3.577538013458252, train_acc0.0
# epoch:2,step500,train_loss2.6344516277313232, train_acc0.0
# epoch:2,step505,train_loss2.5590572357177734, train_acc0.0
# epoch:2,step510,train_loss1.153359293937683, train_acc1.0
# epoch:2,step515,train_loss1.9829052686691284, train_acc1.0
# epoch:2,step520,train_loss1.3341248035430908, train_acc0.0
# epoch:2,step525,train_loss2.6797256469726562, train_acc0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 22
#      20     Batchs.append(Batch)
#      21     print(f"epoch:{epoch},step{batch_id},train_loss{loss.numpy()[0]}, train_acc{acc.numpy()[0]}")
# ---> 22 paddle.save(model.state_dict(), "MyDNN")
#
# File G:\Anaconda3\envs\paddle\lib\site-packages\paddle\framework\io.py:811, in save(obj, path, protocol, **configs)
#     809 elif _is_state_dict(obj):
#     810     if _non_static_mode():
# --> 811         _legacy_save(obj, path, protocol)
#     812     else:
#     813         _legacy_static_save(obj, path, protocol)
#
# File G:\Anaconda3\envs\paddle\lib\site-packages\paddle\framework\io.py:873, in _legacy_save(obj, path, protocol)
#     871 else:
#     872     with _open_file_buffer(path, 'wb') as f:
# --> 873         pickle.dump(saved_obj, f, protocol=protocol)
#
# KeyboardInterrupt:

# %% [markdown]
# # 4.模型评估

# %%
para_state_dict = paddle.load("MyDNN")
model = MyDNN()
model.set_state_dict(para_state_dict)
model.eval()
accs = []
for batch_id, data in enumerate(eval_loader):
    img = data[0]
    label = data[0]
    img = img.flatten(1)
    predict = model(img)
    acc = paddle.metric.accuracy(predict, label)
    accs.append(acc.numpy()[0])

avg_acc = np.mean(accs)
print("当前模型在验证集上的准确率为:",avg_acc)
